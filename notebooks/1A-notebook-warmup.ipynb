# %% [markdown]
# # Jupyter Notebook Warmup
#
# The instructions for this Fundamentals notebook are found on the Lab 1 instructions page. (In general the instructions will be within the notebook itself.)

# %% [markdown]
# ## Jupyter Notebooks

# %%
1+1
# Out:
# 2

# %% [markdown]
# Here is some Markdown formatting:
# * This is **bold**
# * This _is_ italic
# * This is a [link to Calvin's website](https://calvin.edu).

# %%
x = 1.0
x * 2
print("something")
x = x * 2
x * 2
# Out:
# something
# 4.0

# %% [markdown]
# The notebook will print only whatever the last expression in the codeblock is, unless there is an expression which is in a print() function, in which case, that expression will be printed
